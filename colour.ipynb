# %%
import cv2
from matplotlib import pyplot as plt

obraz = cv2.imread(str('1_1.CT.0002.0001.2017.12.15.12.58.43.171875.58588890.IMA'))
plt.figure(figsize=(15,12), dpi=80)
plt.subplot(2,3,1)
plt.imshow(obraz, cmap='twilight')
plt.subplot(2,3,2)
plt.imshow(obraz, cmap='seismic')
plt.subplot(2,3,3)
plt.imshow(obraz, cmap='nipy_spectral')
plt.subplot(2,3,4)
plt.imshow(obraz, cmap='jet')
#turbo nie działa a by było kurcze najlepsze, zobaczę czy da się samemu zdefiniowac kolory :) 
#tu wszystkie kolory: 
#https://matplotlib.org/3.3.3/tutorials/colors/colormaps.html
